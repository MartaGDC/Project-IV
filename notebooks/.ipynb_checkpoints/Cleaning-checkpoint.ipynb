# %% [markdown]
# # Libraries

# %%
import pandas as pd
import pymysql
from getpass import getpass
import sqlalchemy as alch
# import requests
# import json
# from folium import Choropleth, Circle, Marker, Icon, Map
# import time

# %%
df = pd.read_csv("../data/superheroes_nlp_dataset.csv")

# %%
pd.set_option('display.max_columns', None)
df.sample()
# Out:
#        name real_name full_name overall_score  \
# 682  Jestro    Jestro    Jestro            10
#
#                                           history_text  \
# 682  Jestro tried to be a knight, then a Wizard, be...
#
#                                            powers_text  intelligence_score  \
# 682  Jestro isn't shown to have a lot of talents, a...                  90
#
#      strength_score  speed_score  durability_score  power_score  combat_score  \
# 682              10           30                65          100            60
#
#                                            superpowers alter_egos     aliases  \
# 682  ['Agility', 'Darkforce Manipulation', 'Durabil...         []  ['Jester']
#
#     place_of_birth                 first_appearance creator alignment  \
# 682   Nexo Knights  Nexo knights season 1 episode 1     NaN       NaN
#
#     occupation                        base teams relatives gender type_race  \
# 682      Clown  Volcano Lair, Headquarters    []   Unknown   Male     Human
#
#            height          weight eye_color hair_color skin_color  \
# 682  5'2 • 157 cm  176 lb • 79 kg     Black      Black        NaN
#
#                                                    img  has_electrokinesis  \
# 682  /pictures2/portraits/11/050/16049.jpg?v=155456...                 0.0
#
#      has_energy_constructs  has_mind_control_resistance  \
# 682                    0.0                          0.0
#
#      has_matter_manipulation  has_telepathy_resistance  has_mind_control  \
# 682                      0.0                       0.0               0.0
#
#      has_enhanced_hearing  has_dimensional_travel  has_element_control  \
# 682                   0.0                     0.0                  0.0
#
#      has_size_changing  has_fire_resistance  has_fire_control  has_dexterity  \
# 682                0.0                  0.0               0.0            0.0
#
#      has_reality_warping  has_illusions  has_energy_beams  \
# 682                  0.0            1.0               0.0
#
#      has_peak_human_condition  has_shapeshifting  has_heat_resistance  \
# 682                       0.0                0.0                  0.0
#
#      has_jump  has_self-sustenance  has_energy_absorption  \
# 682       0.0                  0.0                    0.0
#
#      has_cold_resistance  has_magic  has_telekinesis  \
# 682                  0.0        1.0              0.0
#
#      has_toxin_and_disease_resistance  has_telepathy  has_regeneration  \
# 682                               0.0            0.0               0.0
#
#      has_immortality  has_teleportation  has_force_fields  \
# 682              0.0                0.0               0.0
#
#      has_energy_manipulation  has_endurance  has_longevity  \
# 682                      0.0            0.0            0.0
#
#      has_weapon-based_powers  has_energy_blasts  has_enhanced_senses  \
# 682                      1.0                0.0                  1.0
#
#      has_invulnerability  has_stealth  has_marksmanship  has_flight  \
# 682                  0.0          1.0               1.0         0.0
#
#      has_accelerated_healing  has_weapons_master  has_intelligence  \
# 682                      0.0                 1.0               1.0
#
#      has_reflexes  has_super_speed  has_durability  has_stamina  has_agility  \
# 682           1.0              0.0             1.0          1.0          1.0
#
#      has_super_strength
# 682                 0.0

# %%
df.shape
# Out:
# (1450, 81)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 81 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   name                              1448 non-null   object
#  1   real_name                         1300 non-null   object
#  2   full_name                         954 non-null    object
#  3   overall_score                     1450 non-null   object
#  4   history_text                      1360 non-null   object
#  5   powers_text                       1084 non-null   object
#  6   intelligence_score                1450 non-null   int64
#  7   strength_score                    1450 non-null   int64
#  8   speed_score                       1450 non-null   int64
#  9   durability_score                  1450 non-null   int64
#  10  power_score                       1450 non-null   int64
#  11  combat_score                      1450 non-null   int64
#  12  superpowers                       1450 non-null   object
#  13  alter_egos                        1450 non-null   object
#  14  aliases                           1450 non-null   object
#  15  place_of_birth                    788 non-null    object
#  16  first_appearance                  1247 non-null   object
#  17  creator                           1311 non-null   object
#  18  alignment                         1368 non-null   object
#  19  occupation                        1014 non-null   object
#  20  base                              870 non-null    object
#  21  teams                             1450 non-null   object
#  22  relatives                         878 non-null    object
#  23  gender                            1305 non-null   object
#  24  type_race                         1043 non-null   object
#  25  height                            1448 non-null   object
#  26  weight                            1448 non-null   object
#  27  eye_color                         1186 non-null   object
#  28  hair_color                        1199 non-null   object
#  29  skin_color                        173 non-null    object
#  30  img                               1363 non-null   object
#  31  has_electrokinesis                1383 non-null   float64
#  32  has_energy_constructs             1383 non-null   float64
#  33  has_mind_control_resistance       1383 non-null   float64
#  34  has_matter_manipulation           1383 non-null   float64
#  35  has_telepathy_resistance          1383 non-null   float64
#  36  has_mind_control                  1383 non-null   float64
#  37  has_enhanced_hearing              1383 non-null   float64
#  38  has_dimensional_travel            1383 non-null   float64
#  39  has_element_control               1383 non-null   float64
#  40  has_size_changing                 1383 non-null   float64
#  41  has_fire_resistance               1383 non-null   float64
#  42  has_fire_control                  1383 non-null   float64
#  43  has_dexterity                     1383 non-null   float64
#  44  has_reality_warping               1383 non-null   float64
#  45  has_illusions                     1383 non-null   float64
#  46  has_energy_beams                  1383 non-null   float64
#  47  has_peak_human_condition          1383 non-null   float64
#  48  has_shapeshifting                 1383 non-null   float64
#  49  has_heat_resistance               1383 non-null   float64
#  50  has_jump                          1383 non-null   float64
#  51  has_self-sustenance               1383 non-null   float64
#  52  has_energy_absorption             1383 non-null   float64
#  53  has_cold_resistance               1383 non-null   float64
#  54  has_magic                         1383 non-null   float64
#  55  has_telekinesis                   1383 non-null   float64
#  56  has_toxin_and_disease_resistance  1383 non-null   float64
#  57  has_telepathy                     1383 non-null   float64
#  58  has_regeneration                  1383 non-null   float64
#  59  has_immortality                   1383 non-null   float64
#  60  has_teleportation                 1383 non-null   float64
#  61  has_force_fields                  1383 non-null   float64
#  62  has_energy_manipulation           1383 non-null   float64
#  63  has_endurance                     1383 non-null   float64
#  64  has_longevity                     1383 non-null   float64
#  65  has_weapon-based_powers           1383 non-null   float64
#  66  has_energy_blasts                 1383 non-null   float64
#  67  has_enhanced_senses               1383 non-null   float64
#  68  has_invulnerability               1383 non-null   float64
#  69  has_stealth                       1383 non-null   float64
#  70  has_marksmanship                  1383 non-null   float64
#  71  has_flight                        1383 non-null   float64
#  72  has_accelerated_healing           1383 non-null   float64
#  73  has_weapons_master                1383 non-null   float64
#  74  has_intelligence                  1383 non-null   float64
#  75  has_reflexes                      1383 non-null   float64
#  76  has_super_speed                   1383 non-null   float64
#  77  has_durability                    1383 non-null   float64
#  78  has_stamina                       1383 non-null   float64
#  79  has_agility                       1383 non-null   float64
#  80  has_super_strength                1383 non-null   float64
# dtypes: float64(50), int64(6), object(25)
# memory usage: 917.7+ KB

# %% [markdown]
# **Drop duplicates (real_name) and na (alignment)**

# %%
df_clean = df

# %%
df_clean.drop_duplicates(subset=["real_name"], inplace=True)

# %%
df_clean.dropna(subset=["alignment"], inplace=True)

# %% [markdown]
# **Rename**

# %%
df_clean.rename(columns= {"has_self-sustenance":"has_self_sustenance", "has_weapon-based_powers": "has_weapon_based_powers"}, inplace = True)

# %% [markdown]
# **Ignore columns with long texts**

# %%
df_clean.drop(columns=["history_text", "powers_text", "superpowers", "alter_egos", "aliases", "first_appearance", "occupation", "teams", "relatives", "height", "weight", "eye_color", "hair_color", "skin_color", "img"], inplace = True)

# %% [markdown]
# **Sum of superpowers per hero**

# %%
df_clean["n_superpowers"] = df_clean.has_electrokinesis + df_clean.has_energy_constructs + df_clean.has_mind_control_resistance + df_clean.has_matter_manipulation + df_clean.has_telepathy_resistance + df_clean.has_mind_control + df_clean.has_enhanced_hearing + df_clean.has_dimensional_travel + df_clean.has_element_control + df_clean.has_size_changing + df_clean.has_fire_resistance + df_clean.has_fire_control + df_clean.has_dexterity + df_clean.has_reality_warping + df_clean.has_illusions + df_clean.has_energy_beams + df_clean.has_peak_human_condition + df_clean.has_shapeshifting + df_clean.has_heat_resistance + df_clean.has_jump + df_clean.has_self_sustenance + df_clean.has_energy_absorption + df_clean.has_cold_resistance + df_clean.has_magic + df_clean.has_telekinesis + df_clean.has_toxin_and_disease_resistance + df_clean.has_telepathy + df_clean.has_regeneration + df_clean.has_immortality + df_clean.has_teleportation + df_clean.has_force_fields + df_clean.has_energy_manipulation + df_clean.has_endurance + df_clean.has_longevity + df_clean.has_weapon_based_powers + df_clean.has_energy_blasts + df_clean.has_enhanced_senses + df_clean.has_invulnerability + df_clean.has_stealth + df_clean.has_marksmanship + df_clean.has_flight + df_clean.has_accelerated_healing + df_clean.has_weapons_master + df_clean.has_intelligence + df_clean.has_reflexes + df_clean.has_super_speed + df_clean.has_durability + df_clean.has_stamina + df_clean.has_agility + df_clean.has_super_strength

# %%
# df_clean.astype({"overall_score": float})

# %%
# Unable to parse string "∞" at position 11
df_clean.loc[df_clean["overall_score"][df["overall_score"] == "∞"].index, "overall_score"] = 100000000

# %%
# df_clean.astype({"overall_score":float})
# Unable to parse string "-" at position 37
df_clean.loc[df_clean["overall_score"][df["overall_score"] == "-"].index, "overall_score"] = float('nan')

# %%
df_clean = df_clean.astype({"overall_score":float})

# %%
df_clean["overall_score"].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# **Coordinates of earth addresses**

# %%
# I wasn't able to retreive the coordinates for all the rows from https://geocode.xyz/
# Too many requests

# %% [markdown]
# **Categorization of superpowers**

# %%
df_clean.sample()
# Out:
#           name real_name full_name  overall_score  intelligence_score  \
# 1012  Platinum  Platinum       NaN            9.0                  95
#
#       strength_score  speed_score  durability_score  power_score  \
# 1012              20           20                70           50
#
#       combat_score place_of_birth    creator alignment         base  gender  \
# 1012            50    Magnus Labs  DC Comics      Good  Magnus Labs  Female
#
#      type_race  has_electrokinesis  has_energy_constructs  \
# 1012       NaN                 0.0                    0.0
#
#       has_mind_control_resistance  has_matter_manipulation  \
# 1012                          0.0                      0.0
#
#       has_telepathy_resistance  has_mind_control  has_enhanced_hearing  \
# 1012                       0.0               0.0                   0.0
#
#       has_dimensional_travel  has_element_control  has_size_changing  \
# 1012                     0.0                  0.0                0.0
#
#       has_fire_resistance  has_fire_control  has_dexterity  \
# 1012                  0.0               0.0            0.0
#
#       has_reality_warping  has_illusions  has_energy_beams  \
# 1012                  0.0            0.0               0.0
#
#       has_peak_human_condition  has_shapeshifting  has_heat_resistance  \
# 1012                       0.0                0.0                  0.0
#
#       has_jump  has_self_sustenance  has_energy_absorption  \
# 1012       0.0                  0.0                    0.0
#
#       has_cold_resistance  has_magic  has_telekinesis  \
# 1012                  0.0        0.0              0.0
#
#       has_toxin_and_disease_resistance  has_telepathy  has_regeneration  \
# 1012                               1.0            0.0               0.0
#
#       has_immortality  has_teleportation  has_force_fields  \
# 1012              0.0                0.0               0.0
#
#       has_energy_manipulation  has_endurance  has_longevity  \
# 1012                      0.0            0.0            0.0
#
#       has_weapon_based_powers  has_energy_blasts  has_enhanced_senses  \
# 1012                      0.0                0.0                  0.0
#
#       has_invulnerability  has_stealth  has_marksmanship  has_flight  \
# 1012                  1.0          0.0               0.0         0.0
#
#       has_accelerated_healing  has_weapons_master  has_intelligence  \
# 1012                      0.0                 0.0               0.0
#
#       has_reflexes  has_super_speed  has_durability  has_stamina  has_agility  \
# 1012           0.0              0.0             1.0          0.0          1.0
#
#       has_super_strength  n_superpowers
# 1012                 0.0            4.0

# %%
df_clean["energy_powers"] = df_clean["has_electrokinesis"] + df_clean["has_energy_constructs"] + df_clean["has_energy_beams"] + df_clean["has_energy_blasts"] + df_clean["has_energy_manipulation"] + df_clean["has_energy_absorption"] + df_clean["has_force_fields"]

# %%
df_clean["matter_powers"] = df_clean["has_matter_manipulation"] + df_clean["has_element_control"] + df_clean["has_telekinesis"] + df_clean["has_fire_control"]

# %%
df_clean["self_powers"] = df_clean["has_size_changing"] +  df_clean["has_shapeshifting"] +  df_clean["has_teleportation"]

# %%
df_clean["reality_powers"] = df_clean["has_reality_warping"] + df_clean["has_illusions"] + df_clean["has_magic"] + df_clean["has_dimensional_travel"]

# %%
df_clean["mind_powers"] = df_clean["has_mind_control"] + df_clean["has_telepathy"] + df_clean["has_intelligence"]

# %%
df_clean["resistance_powers"] = df_clean["has_mind_control_resistance"] + df_clean["has_telepathy_resistance"] + df_clean["has_heat_resistance"] + df_clean["has_fire_resistance"] + df_clean["has_cold_resistance"] + df_clean["has_toxin_and_disease_resistance"]

# %%
df_clean["invulnerability"] = df_clean["has_peak_human_condition"] + df_clean["has_immortality"] + df_clean["has_longevity"] + df_clean["has_invulnerability"] + df_clean["has_regeneration"] + df_clean["has_accelerated_healing"] + df_clean["has_self_sustenance"]

# %%
df_clean["supersenses"] = df_clean["has_enhanced_senses"] + df_clean["has_enhanced_hearing"]

# %%
df_clean["stamina"] = df_clean["has_endurance"] + df_clean["has_durability"] +  df_clean["has_stamina"]

# %%
df_clean["capabilities"] = df_clean["has_dexterity"] + df_clean["has_agility"] + df_clean["has_reflexes"] + df_clean["has_marksmanship"]

# %%
df_clean["jump_flight"] = df_clean["has_jump"] +  df_clean["has_flight"]

# %%
df_clean["stealth"] = df_clean["has_stealth"]
df_clean["speed"] = df_clean["has_super_speed"]
df_clean["strength"] = df_clean["has_super_strength"]

# %%
df_clean["weapons"] = df_clean["has_weapon_based_powers"] + df_clean["has_weapons_master"]

# %%
df_clean.sample()
# Out:
#              name        real_name        full_name  overall_score  \
# 1010  Plastic Man  Patrick O'Brian  Patrick O'Brian           10.0
#
#       intelligence_score  strength_score  speed_score  durability_score  \
# 1010                  75              65           25               100
#
#       power_score  combat_score place_of_birth    creator alignment base  \
# 1010          100            55            NaN  DC Comics      Good  NaN
#
#      gender type_race  has_electrokinesis  has_energy_constructs  \
# 1010   Male     Human                 0.0                    0.0
#
#       has_mind_control_resistance  has_matter_manipulation  \
# 1010                          0.0                      0.0
#
#       has_telepathy_resistance  has_mind_control  has_enhanced_hearing  \
# 1010                       1.0               0.0                   0.0
#
#       has_dimensional_travel  has_element_control  has_size_changing  \
# 1010                     0.0                  0.0                1.0
#
#       has_fire_resistance  has_fire_control  has_dexterity  \
# 1010                  0.0               0.0            0.0
#
#       has_reality_warping  has_illusions  has_energy_beams  \
# 1010                  0.0            0.0               0.0
#
#       has_peak_human_condition  has_shapeshifting  has_heat_resistance  \
# 1010                       0.0                1.0                  0.0
#
#       has_jump  has_self_sustenance  has_energy_absorption  \
# 1010       0.0                  0.0                    0.0
#
#       has_cold_resistance  has_magic  has_telekinesis  \
# 1010                  0.0        0.0              0.0
#
#       has_toxin_and_disease_resistance  has_telepathy  has_regeneration  \
# 1010                               0.0            0.0               0.0
#
#       has_immortality  has_teleportation  has_force_fields  \
# 1010              1.0                0.0               0.0
#
#       has_energy_manipulation  has_endurance  has_longevity  \
# 1010                      0.0            0.0            0.0
#
#       has_weapon_based_powers  has_energy_blasts  has_enhanced_senses  \
# 1010                      0.0                0.0                  0.0
#
#       has_invulnerability  has_stealth  has_marksmanship  has_flight  \
# 1010                  1.0          1.0               0.0         0.0
#
#       has_accelerated_healing  has_weapons_master  has_intelligence  \
# 1010                      1.0                 0.0               0.0
#
#       has_reflexes  has_super_speed  has_durability  has_stamina  has_agility  \
# 1010           0.0              0.0             1.0          0.0          1.0
#
#       has_super_strength  n_superpowers  energy_powers  matter_powers  \
# 1010                 1.0           10.0            0.0            0.0
#
#       self_powers  reality_powers  mind_powers  resistance_powers  \
# 1010          2.0             0.0          0.0                1.0
#
#       invulnerability  supersenses  stamina  capabilities  jump_flight  \
# 1010              3.0          0.0      1.0           1.0          0.0
#
#       stealth  speed  strength  weapons
# 1010      1.0    0.0       1.0      0.0

# %%
df_clean.to_csv("../data/heros.csv")
